# %% [markdown]
# <a href="https://colab.research.google.com/github/Sayed-Ali-Raza-Naqvi/CodexCue_Sentiment-Analysis_Project/blob/main/CodexCue_Sentiment_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Twitter Sentiment Analysis**
#
# ---
#
# The dataset used is 'Twitter Sentiment Analysis' from Kaggle.

# %% [markdown]
# Importing all the necessary libraries and modules.

# %%
import pandas as pd
import re
from nltk.stem import WordNetLemmatizer
import nltk
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.pipeline import Pipeline

# %% [markdown]
# Reading the datasets.

# %%
training_data = pd.read_csv('/content/twitter_training.csv', names=['id', 'entity', 'sentiment', 'content'])
validation_data = pd.read_csv('/content/twitter_validation.csv', names=['id', 'entity', 'sentiment', 'content'])

# %%
training_data.sample(5)
# Out:
#           id               entity sentiment  \
# 45706  11845              Verizon   Neutral
# 1579    2676          Borderlands  Positive
# 17365   9777    PlayStation5(PS5)  Positive
# 61982   5026  GrandTheftAuto(GTA)   Neutral
# 69636   3932        Cyberpunk2077  Negative
#
#                                                  content
# 45706  Video : Just Cavs'featuring Kevin Little Love ...
# 1579                                   Hee, yasss! < 333
# 17365                      I like competitiveness better
# 61982  This is the Grand Theft Auto GTA That that cam...
# 69636  There's only two outcomes for Cyberpunk 2077.....

# %%
validation_data.sample(5)
# Out:
#         id                             entity sentiment  \
# 918    930                     AssassinsCreed  Positive
# 766   4275                              CS-GO   Neutral
# 966   4313                              CS-GO   Neutral
# 727   8943                             Nvidia   Neutral
# 836  10054  PlayerUnknownsBattlegrounds(PUBG)  Negative
#
#                                                content
# 918                               😅 I love you guys. 😘
# 766  Don't jump me... @CSGO #CSGO\n\n🔗 medal.tv/cli...
# 966  The Russians from cs:go are starting to invade...
# 727  Half are political accounts, most of them I ha...
# 836  India Bans 118 Chinese apps including PUBG #PU...

# %% [markdown]
# Checking the shape of the datasets.

# %%
print(f'Training data shape: {training_data.shape}')
print(f'Validation data shape: {validation_data.shape}')
# Out:
# Training data shape: (74682, 4)
# Validation data shape: (1000, 4)

# %% [markdown]
# Getting the null values.

# %%
training_data.isnull().sum()
# Out:
# id             0
# entity         0
# sentiment      0
# content      686
# dtype: int64

# %%
validation_data.isnull().sum()
# Out:
# id           0
# entity       0
# sentiment    0
# content      0
# dtype: int64

# %% [markdown]
# Removing the data containing null values.

# %%
training_data = training_data.dropna(subset=['content'])

# %%
training_data.isnull().sum()
# Out:
# id           0
# entity       0
# sentiment    0
# content      0
# dtype: int64

# %%
training_data.shape
# Out:
# (73996, 4)

# %% [markdown]
# Changing the string values into numbers. Ordinal encoding is done.

# %%
ordinal_mapping = {'Neutral': 0, 'Positive': 1, 'Negative': 2, 'Irrelevant': 3}
training_data['sentiment_encoded'] = training_data['sentiment'].map(ordinal_mapping)
validation_data['sentiment_encoded'] = validation_data['sentiment'].map(ordinal_mapping)

# %%
training_data.sample(5)
# Out:
#           id          entity   sentiment  \
# 8089    9389       Overwatch     Neutral
# 9864   12899   Xbox(Xseries)    Positive
# 40629   1372     Battlefield  Irrelevant
# 9899   12904   Xbox(Xseries)    Positive
# 26212    900  AssassinsCreed    Positive
#
#                                                  content  sentiment_encoded
# 8089   anna's ult group is clc. anna is a regular acc...                  0
# 9864   Well fuck that's only 2 months before Xbox Ser...                  1
# 40629  . New Video..... Flying Is Dangerous (Battlefi...                  3
# 9899   Boy am I chomping at a bit for this @xbox show...                  1
# 26212                                      Can't it wait                  1

# %%
validation_data.sample(5)
# Out:
#        id                     entity sentiment  \
# 838  9788          PlayStation5(PS5)  Positive
# 80   8121                  Microsoft   Neutral
# 955  4158                      CS-GO  Positive
# 828  1857  CallOfDutyBlackopsColdWar  Negative
# 543   706                ApexLegends  Negative
#
#                                                content  sentiment_encoded
# 838  Very much looking forward to getting new info ...                  1
# 80   “the Free Software movement is dead. Linux doe...                  0
# 955                        bhopping in csgo is so cozy                  1
# 828  Score Streaks are the worst thing to happen in...                  2
# 543  I’m not gonna spend any more money on #apexleg...                  2

# %% [markdown]
# Downloading NLTK resouces.
#
# stopwords: Downloads a list of common stopwords in various languages.
#
# punkt: Downloads the Punkt tokenizer models for tokenization.
#
# wordnet: Downloads the WordNet lexical database for tasks such as lemmatization.

# %%
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# Getting english stop words.
#
# Nltk stop words are widely used words (such as “the,” “a,” “an,” or “in”) that a search engine has been configured to disregard while indexing and retrieving entries.

# %%
english_stopwords = set(stopwords.words('english'))

# %% [markdown]
# Instantiating WordNetLemmatizer object for lemmatization.
#
# Lemmatization is the process of reducing words to their base or dictionary form.

# %%
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# Function to preprocess the tweet column.

# %%
def preprocess_content(text):
  cleaned_text = re.sub('[^a-zA-Z]', ' ', text.lower())
  tokens = nltk.word_tokenize(cleaned_text)
  lemmatized_tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stopwords.words('english')]
  processed_text = ' '.join(lemmatized_tokens)

  return processed_text

# %% [markdown]
# Applying the function on the tweets column and then saving the result in another column.

# %%
training_data['processed_content'] = training_data['content'].apply(preprocess_content)

# %%
validation_data['processed_content'] = validation_data['content'].apply(preprocess_content)

# %%
training_data.head()
# Out:
#      id       entity sentiment  \
# 0  2401  Borderlands  Positive
# 1  2401  Borderlands  Positive
# 2  2401  Borderlands  Positive
# 3  2401  Borderlands  Positive
# 4  2401  Borderlands  Positive
#
#                                              content  sentiment_encoded  \
# 0  im getting on borderlands and i will murder yo...                  1
# 1  I am coming to the borders and I will kill you...                  1
# 2  im getting on borderlands and i will kill you ...                  1
# 3  im coming on borderlands and i will murder you...                  1
# 4  im getting on borderlands 2 and i will murder ...                  1
#
#               processed_content
# 0  im getting borderland murder
# 1            coming border kill
# 2    im getting borderland kill
# 3   im coming borderland murder
# 4  im getting borderland murder

# %%
validation_data.head()
# Out:
#      id     entity   sentiment  \
# 0  3364   Facebook  Irrelevant
# 1   352     Amazon     Neutral
# 2  8312  Microsoft    Negative
# 3  4371      CS-GO    Negative
# 4  4433     Google     Neutral
#
#                                              content  sentiment_encoded  \
# 0  I mentioned on Facebook that I was struggling ...                  3
# 1  BBC News - Amazon boss Jeff Bezos rejects clai...                  0
# 2  @Microsoft Why do I pay for WORD when it funct...                  2
# 3  CSGO matchmaking is so full of closet hacking,...                  2
# 4  Now the President is slapping Americans in the...                  0
#
#                                    processed_content
# 0  mentioned facebook struggling motivation go ru...
# 1  bbc news amazon bos jeff bezos reject claim co...
# 2  microsoft pay word function poorly samsungus c...
# 3  csgo matchmaking full closet hacking truly awf...
# 4  president slapping american face really commit...

# %% [markdown]
# Train test splitting with 80% training data and 20% testing data.

# %%
X_train, X_test, Y_train, Y_test = train_test_split(training_data['processed_content'], training_data['sentiment'],
                                                    test_size=0.2, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((59196,), (14800,))

# %% [markdown]
# Using Pipeline to perform TF-IFD and model training.
#
# TfidfVectorizer is a technique for converting text data into a matrix of TF-IDF features.
#
# Using Logistic Regression as training model.

# %%
model = Pipeline([
    ('tfidf', TfidfVectorizer()),
    ('clf', LogisticRegression())
])

# %% [markdown]
# Making prediction and getting the accuracy score.

# %%
model.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('clf', LogisticRegression())])

# %% [markdown]
# Model Prediction and accuracy score.

# %%
prediction = model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, prediction)
print(f'Accuracy Score: {accuracy}')
# Out:
# Accuracy Score: 0.7772972972972974

# %%
print(classification_report(Y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#   Irrelevant       0.83      0.66      0.74      2696
#     Negative       0.75      0.86      0.80      4380
#      Neutral       0.80      0.73      0.76      3605
#     Positive       0.77      0.81      0.79      4119
#
#     accuracy                           0.78     14800
#    macro avg       0.79      0.76      0.77     14800
# weighted avg       0.78      0.78      0.78     14800

# %% [markdown]
# Importing pickle to save the model for future predictions and for deployment on the website.

# %%
import pickle

# %%
filename = 'twitter_sentiment_analysis_model.pkl'
pickle.dump(model, open(filename, 'wb'))
